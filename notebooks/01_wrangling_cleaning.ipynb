# %% [markdown]
# # Contents
# 1. Imports
# 2. Checks
# 3. Wrangling
# 4. Exports

# %% [markdown]
# # 1. Imports

# %%
# Libraries
import pandas as pd
import numpy as np
import os

# %%
# Path
path = r'/Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling/data'

# %%
# Dataset
df_quality = pd.read_csv(os.path.join(path, 'original','coffee_quality.csv'), index_col = False)

# %% [markdown]
# ##### Source: [Kaggle](https://www.kaggle.com/datasets/adampq/coffee-quality-with-locations-of-origin/data)

# %% [markdown]
# # 2. Checks

# %%
# Dimensions
df_quality.shape
# Out:
# (1339, 22)

# %%
# Configuration
pd.set_option('display.max_columns', None) # Display all columns

# %%
# Preview
df_quality.head()
# Out:
#    REC_ID  Species Continent.of.Origin Country.of.Origin  Harvest.Year  \
# 0       0  Arabica              Africa          Ethiopia        2014.0
# 1       1  Arabica              Africa          Ethiopia        2014.0
# 2       2  Arabica       North America         Guatemala           NaN
# 3       3  Arabica              Africa          Ethiopia        2014.0
# 4       4  Arabica              Africa          Ethiopia        2014.0
#
#   Expiration  Variety  Color Processing.Method  Aroma  Flavor  Aftertaste  \
# 0   04/03/16      NaN  Green      Washed / Wet   8.67    8.83        8.67
# 1   04/03/16    Other  Green      Washed / Wet   8.75    8.67        8.50
# 2   05/31/11  Bourbon    NaN               NaN   8.42    8.50        8.42
# 3   03/25/16      NaN  Green     Natural / Dry   8.17    8.58        8.42
# 4   04/03/16    Other  Green      Washed / Wet   8.25    8.50        8.25
#
#    Acidity  Body  Balance  Uniformity  Clean.Cup  Sweetness  Moisture  \
# 0     8.75  8.50     8.42        10.0       10.0       10.0      0.12
# 1     8.58  8.42     8.42        10.0       10.0       10.0      0.12
# 2     8.42  8.33     8.42        10.0       10.0       10.0      0.00
# 3     8.42  8.50     8.25        10.0       10.0       10.0      0.11
# 4     8.50  8.42     8.33        10.0       10.0       10.0      0.12
#
#    Quakers  Category.One.Defects  Category.Two.Defects
# 0        0                     0                     0
# 1        0                     0                     1
# 2        0                     0                     0
# 3        0                     0                     2
# 4        0                     0                     2

# %%
# Reset configuration
pd.reset_option('display.max_columns')

# %%
# Descriptive statistics - Raw dataset
df_quality.describe()
# Out:
#             REC_ID  Harvest.Year        Aroma       Flavor   Aftertaste  \
# count  1339.000000   1279.000000  1339.000000  1339.000000  1339.000000
# mean    669.000000   2013.567631     7.566706     7.520426     7.401083
# std     386.680316      1.808496     0.377560     0.398442     0.404463
# min       0.000000   2009.000000     0.000000     0.000000     0.000000
# 25%     334.500000   2012.000000     7.420000     7.330000     7.250000
# 50%     669.000000   2013.000000     7.580000     7.580000     7.420000
# 75%    1003.500000   2015.000000     7.750000     7.750000     7.580000
# max    1338.000000   2018.000000     8.750000     8.830000     8.670000
#
#            Acidity         Body      Balance   Uniformity    Clean.Cup  \
# count  1339.000000  1339.000000  1339.000000  1339.000000  1339.000000
# mean      7.535706     7.517498     7.518013     9.834877     9.835108
# std       0.379827     0.370064     0.408943     0.554591     0.763946
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.330000     7.330000     7.330000    10.000000    10.000000
# 50%       7.580000     7.500000     7.500000    10.000000    10.000000
# 75%       7.750000     7.670000     7.750000    10.000000    10.000000
# max       8.750000     8.580000     8.750000    10.000000    10.000000
#
#          Sweetness     Moisture      Quakers  Category.One.Defects  \
# count  1339.000000  1339.000000  1339.000000           1339.000000
# mean      9.856692     0.088379     0.173264              0.479462
# std       0.616102     0.048287     0.831824              2.549683
# min       0.000000     0.000000     0.000000              0.000000
# 25%      10.000000     0.090000     0.000000              0.000000
# 50%      10.000000     0.110000     0.000000              0.000000
# 75%      10.000000     0.120000     0.000000              0.000000
# max      10.000000     0.280000    11.000000             63.000000
#
#        Category.Two.Defects
# count           1339.000000
# mean               3.556385
# std                5.312541
# min                0.000000
# 25%                0.000000
# 50%                2.000000
# 75%                4.000000
# max               55.000000

# %% [markdown]
# # 3. Wrangling

# %% [markdown]
# ## 3.1. Dropping columns

# %%
# Null values
df_quality.isnull().sum()
# Out:
# REC_ID                    0
# Species                   0
# Continent.of.Origin       1
# Country.of.Origin         1
# Harvest.Year             60
# Expiration                0
# Variety                 226
# Color                   270
# Processing.Method       170
# Aroma                     0
# Flavor                    0
# Aftertaste                0
# Acidity                   0
# Body                      0
# Balance                   0
# Uniformity                0
# Clean.Cup                 0
# Sweetness                 0
# Moisture                  0
# Quakers                   0
# Category.One.Defects      0
# Category.Two.Defects      0
# dtype: int64

# %%
# Remove index column
df_quality_v1 = df_quality.drop(columns = ['REC_ID'])

# %%
# Dimensions
df_quality_v1.shape
# Out:
# (1339, 21)

# %% [markdown]
# ## 3.2. Renaming columns

# %%
# Column names
df_quality_v1.columns
# Out:
# Index(['Species', 'Continent.of.Origin', 'Country.of.Origin', 'Harvest.Year',
#        'Expiration', 'Variety', 'Color', 'Processing.Method', 'Aroma',
#        'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity',
#        'Clean.Cup', 'Sweetness', 'Moisture', 'Quakers', 'Category.One.Defects',
#        'Category.Two.Defects'],
#       dtype='object')

# %%
# Copy dataframe
df_quality_v2 = df_quality_v1.copy()

# Change '.' to '_'
df_quality_v2.rename(columns = {
    'Continent.of.Origin': 'Continent_of_Origin',
    'Country.of.Origin': 'Country_of_Origin',
    'Harvest.Year': 'Harvest_Year',
    'Processing.Method': 'Processing_Method',
    'Clean.Cup': 'Clean_Cup',
    'Category.One.Defects': 'Category_One_Defects',
    'Category.Two.Defects': 'Category_Two_Defects'
}, inplace = True)

# %%
# Column names
df_quality_v2.columns
# Out:
# Index(['Species', 'Continent_of_Origin', 'Country_of_Origin', 'Harvest_Year',
#        'Expiration', 'Variety', 'Color', 'Processing_Method', 'Aroma',
#        'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity',
#        'Clean_Cup', 'Sweetness', 'Moisture', 'Quakers', 'Category_One_Defects',
#        'Category_Two_Defects'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Data types

# %%
# Data types
df_quality_v2.dtypes
# Out:
# Species                  object
# Continent_of_Origin      object
# Country_of_Origin        object
# Harvest_Year            float64
# Expiration               object
# Variety                  object
# Color                    object
# Processing_Method        object
# Aroma                   float64
# Flavor                  float64
# Aftertaste              float64
# Acidity                 float64
# Body                    float64
# Balance                 float64
# Uniformity              float64
# Clean_Cup               float64
# Sweetness               float64
# Moisture                float64
# Quakers                   int64
# Category_One_Defects      int64
# Category_Two_Defects      int64
# dtype: object

# %%
# Copy dataframe
df_quality_v3 = df_quality_v2.copy()

# Convert 'Harvest_Year' to datetime
df_quality_v3['Harvest_Year'] = pd.to_datetime(
    df_quality_v3['Harvest_Year'],  # Replace NaN with 1900 and cast to integer
    format = '%Y')  # Specify format as year

# Convert 'Expiration' to datetime
df_quality_v3['Expiration'] = pd.to_datetime(
    df_quality_v3['Expiration'], 
    format = '%m/%d/%y')

# %%
# Data types
df_quality_v3.dtypes
# Out:
# Species                         object
# Continent_of_Origin             object
# Country_of_Origin               object
# Harvest_Year            datetime64[ns]
# Expiration              datetime64[ns]
# Variety                         object
# Color                           object
# Processing_Method               object
# Aroma                          float64
# Flavor                         float64
# Aftertaste                     float64
# Acidity                        float64
# Body                           float64
# Balance                        float64
# Uniformity                     float64
# Clean_Cup                      float64
# Sweetness                      float64
# Moisture                       float64
# Quakers                          int64
# Category_One_Defects             int64
# Category_Two_Defects             int64
# dtype: object

# %% [markdown]
# ## 3.4 Accuracy

# %%
# Basic statistics
df_quality_v3.describe()
# Out:
#                         Harvest_Year                     Expiration  \
# count                           1279                           1339
# mean   2013-07-26 21:53:54.089132032  2015-03-22 19:15:00.672143360
# min              2009-01-01 00:00:00            2011-04-09 00:00:00
# 25%              2012-01-01 00:00:00            2013-08-17 00:00:00
# 50%              2013-01-01 00:00:00            2015-04-03 00:00:00
# 75%              2015-01-01 00:00:00            2016-07-16 00:00:00
# max              2018-01-01 00:00:00            2019-01-19 00:00:00
# std                              NaN                            NaN
#
#              Aroma       Flavor   Aftertaste      Acidity         Body  \
# count  1339.000000  1339.000000  1339.000000  1339.000000  1339.000000
# mean      7.566706     7.520426     7.401083     7.535706     7.517498
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.420000     7.330000     7.250000     7.330000     7.330000
# 50%       7.580000     7.580000     7.420000     7.580000     7.500000
# 75%       7.750000     7.750000     7.580000     7.750000     7.670000
# max       8.750000     8.830000     8.670000     8.750000     8.580000
# std       0.377560     0.398442     0.404463     0.379827     0.370064
#
#            Balance   Uniformity    Clean_Cup    Sweetness     Moisture  \
# count  1339.000000  1339.000000  1339.000000  1339.000000  1339.000000
# mean      7.518013     9.834877     9.835108     9.856692     0.088379
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.330000    10.000000    10.000000    10.000000     0.090000
# 50%       7.500000    10.000000    10.000000    10.000000     0.110000
# 75%       7.750000    10.000000    10.000000    10.000000     0.120000
# max       8.750000    10.000000    10.000000    10.000000     0.280000
# std       0.408943     0.554591     0.763946     0.616102     0.048287
#
#            Quakers  Category_One_Defects  Category_Two_Defects
# count  1339.000000           1339.000000           1339.000000
# mean      0.173264              0.479462              3.556385
# min       0.000000              0.000000              0.000000
# 25%       0.000000              0.000000              0.000000
# 50%       0.000000              0.000000              2.000000
# 75%       0.000000              0.000000              4.000000
# max      11.000000             63.000000             55.000000
# std       0.831824              2.549683              5.312541

# %%
# Configuration
pd.set_option('display.max_rows', None) # Display all rows

# %%
# Frequency tables

# %%
df_quality_v3['Species'].value_counts(dropna = True)
# Out:
# Species
# Arabica    1311
# Robusta      28
# Name: count, dtype: int64

# %%
df_quality_v3['Continent_of_Origin'].value_counts(dropna = True)
# Out:
# Continent_of_Origin
# North America    665
# South America    328
# Asia             182
# Africa           162
# Oceania            1
# Name: count, dtype: int64

# %%
df_quality_v3['Country_of_Origin'].value_counts(dropna = True)
# Out:
# Country_of_Origin
# Mexico              236
# Colombia            183
# Guatemala           181
# Brazil              132
# United States        87
# Taiwan               75
# Honduras             53
# Costa Rica           51
# Ethiopia             44
# Tanzania             40
# Uganda               36
# Thailand             32
# Nicaragua            26
# Kenya                25
# El Salvador          21
# Indonesia            20
# China                16
# India                14
# Malawi               11
# Peru                 10
# Vietnam               8
# Myanmar               8
# Haiti                 6
# Philippines           5
# Panama                4
# Ecuador               3
# Laos                  3
# Burundi               2
# Papua New Guinea      1
# Japan                 1
# Rwanda                1
# Zambia                1
# Mauritius             1
# Cote dIvoire          1
# Name: count, dtype: int64

# %%
df_quality_v3['Harvest_Year'].value_counts(dropna = True)
# Out:
# Harvest_Year
# 2012-01-01    354
# 2014-01-01    252
# 2013-01-01    210
# 2015-01-01    157
# 2016-01-01    131
# 2017-01-01     89
# 2011-01-01     35
# 2010-01-01     30
# 2009-01-01     20
# 2018-01-01      1
# Name: count, dtype: int64

# %%
df_quality_v3['Expiration'].value_counts(dropna = True)
# Out:
# Expiration
# 2014-12-26    25
# 2013-07-11    25
# 2013-06-06    19
# 2013-08-30    18
# 2013-07-26    15
# 2014-03-29    13
# 2016-10-07    13
# 2013-09-27    13
# 2011-06-17    12
# 2018-10-20    11
# 2013-09-17    11
# 2015-12-12    10
# 2013-09-10    10
# 2015-12-18    10
# 2018-06-01     9
# 2013-09-11     9
# 2017-08-16     9
# 2017-04-06     9
# 2013-02-22     8
# 2015-11-23     8
# 2015-11-04     8
# 2013-07-03     8
# 2013-09-04     8
# 2016-05-22     7
# 2015-04-26     7
# 2011-05-31     7
# 2013-08-31     7
# 2015-06-27     7
# 2018-08-22     7
# 2016-07-16     7
# 2015-06-26     7
# 2012-12-02     7
# 2018-06-22     6
# 2015-08-25     6
# 2015-05-15     6
# 2014-02-26     6
# 2013-02-12     6
# 2013-08-01     6
# 2016-11-15     6
# 2017-05-18     6
# 2013-05-24     6
# 2016-03-12     6
# 2013-04-06     6
# 2015-01-17     6
# 2016-06-08     6
# 2016-03-20     5
# 2012-10-27     5
# 2015-06-16     5
# 2013-02-28     5
# 2014-09-03     5
# 2013-07-02     5
# 2013-03-05     5
# 2018-02-13     5
# 2012-06-13     5
# 2018-08-23     5
# 2013-04-02     5
# 2015-06-30     5
# 2013-09-13     5
# 2014-04-26     5
# 2015-06-09     5
# 2013-09-14     5
# 2015-10-16     5
# 2018-09-08     4
# 2013-10-09     4
# 2012-09-21     4
# 2016-01-15     4
# 2011-04-13     4
# 2013-07-09     4
# 2012-02-09     4
# 2015-01-21     4
# 2017-05-23     4
# 2018-06-06     4
# 2015-04-08     4
# 2012-08-22     4
# 2012-08-15     4
# 2015-12-15     4
# 2015-10-15     4
# 2016-04-29     4
# 2018-04-06     4
# 2016-05-11     4
# 2018-05-11     4
# 2018-02-20     4
# 2016-07-05     4
# 2016-04-03     4
# 2013-01-22     4
# 2016-03-30     4
# 2014-05-29     4
# 2015-05-01     4
# 2013-09-12     4
# 2015-05-27     3
# 2014-06-21     3
# 2013-01-12     3
# 2015-07-15     3
# 2013-09-19     1
# 2015-04-25     1
# 2018-06-26     1
# 2017-08-31     1
# 2017-11-24     1
# 2017-10-04     1
# 2016-03-09     1
# 2015-03-05     1
# 2017-10-13     1
# 2018-02-09     1
# 2014-08-30     1
# 2018-04-19     1
# 2016-06-10     1
# 2014-05-10     1
# 2011-04-30     1
# 2016-05-25     1
# 2016-07-19     1
# 2018-08-10     1
# 2017-03-25     1
# 2017-04-08     1
# 2018-02-06     1
# 2018-10-13     1
# 2012-07-18     1
# 2013-07-20     1
# 2014-10-01     1
# 2017-06-23     1
# 2014-12-27     1
# 2015-04-03     1
# 2016-08-02     1
# 2017-02-15     1
# 2019-01-09     1
# 2011-09-03     1
# 2018-10-17     1
# 2014-07-17     1
# 2018-11-28     1
# 2015-06-25     1
# 2013-02-15     1
# 2016-11-02     1
# 2012-03-22     1
# 2017-06-02     1
# 2012-03-21     1
# 2017-01-24     1
# 2015-07-09     1
# 2014-07-10     1
# 2014-01-21     1
# 2018-08-08     1
# 2017-04-04     1
# 2018-09-19     1
# 2015-12-23     1
# Name: count, dtype: int64

# %%
df_quality_v3['Variety'].value_counts(dropna = True)
# Out:
# Variety
# Caturra                  256
# Bourbon                  226
# Typica                   211
# Other                    110
# Catuai                    74
# Hawaiian Kona             44
# Yellow Bourbon            35
# Mundo Novo                33
# Catimor                   20
# SL14                      17
# SL28                      15
# Pacas                     13
# Gesha                     12
# SL34                       8
# Pacamara                   8
# Arusha                     6
# Peaberry                   5
# Sumatra                    3
# Mandheling                 3
# Ruiru 11                   2
# Blue Mountain              2
# Ethiopian Yirgacheffe      2
# Java                       2
# Ethiopian Heirlooms        1
# Moka Peaberry              1
# Sulawesi                   1
# Sumatra Lintong            1
# Marigojipe                 1
# Pache Comun                1
# Name: count, dtype: int64

# %%
df_quality_v3['Color'].value_counts(dropna = True)
# Out:
# Color
# Green           870
# Bluish-Green    114
# Blue-Green       85
# Name: count, dtype: int64

# %%
df_quality_v3['Processing_Method'].value_counts(dropna = True)
# Out:
# Processing_Method
# Washed / Wet                 815
# Natural / Dry                258
# Semi-washed / Semi-pulped     56
# Other                         26
# Pulped natural / honey        14
# Name: count, dtype: int64

# %%
df_quality_v3['Aroma'].value_counts(dropna = True)
# Out:
# Aroma
# 7.67    179
# 7.50    165
# 7.58    152
# 7.75    125
# 7.42    122
# 7.83    103
# 7.33     98
# 7.25     78
# 7.92     59
# 8.00     48
# 7.17     45
# 7.08     28
# 7.00     23
# 8.08     20
# 8.17     20
# 6.92     14
# 8.42      9
# 8.25      9
# 6.83      9
# 6.75      7
# 8.33      7
# 6.67      3
# 8.50      3
# 6.50      2
# 8.67      2
# 7.81      2
# 5.08      1
# 8.75      1
# 6.42      1
# 6.17      1
# 8.58      1
# 6.33      1
# 0.00      1
# Name: count, dtype: int64

# %%
df_quality_v3['Flavor'].value_counts(dropna = True)
# Out:
# Flavor
# 7.50    166
# 7.58    166
# 7.67    148
# 7.75    126
# 7.42    116
# 7.33    111
# 7.83     89
# 7.25     64
# 7.17     56
# 7.92     45
# 7.08     42
# 8.00     41
# 7.00     36
# 8.17     18
# 6.83     17
# 6.92     15
# 8.08     14
# 6.75     10
# 6.50      9
# 8.25      7
# 8.33      5
# 8.42      5
# 6.58      5
# 6.67      5
# 8.50      5
# 8.67      4
# 6.33      3
# 7.88      2
# 6.17      2
# 8.58      2
# 6.42      1
# 8.83      1
# 6.08      1
# 7.81      1
# 0.00      1
# Name: count, dtype: int64

# %%
df_quality_v3['Aftertaste'].value_counts(dropna = True)
# Out:
# Aftertaste
# 7.50    164
# 7.33    153
# 7.42    129
# 7.58    126
# 7.25    104
# 7.67    102
# 7.17     91
# 7.75     87
# 7.83     65
# 7.00     62
# 7.08     45
# 6.83     36
# 6.92     36
# 8.00     27
# 7.92     22
# 6.67     14
# 6.75     10
# 6.17      8
# 8.08      7
# 8.17      7
# 6.50      7
# 6.33      6
# 6.58      6
# 8.25      4
# 8.50      4
# 6.42      4
# 8.42      3
# 8.58      2
# 8.33      2
# 6.25      1
# 8.67      1
# 7.38      1
# 7.56      1
# 7.88      1
# 0.00      1
# Name: count, dtype: int64

# %%
df_quality_v3['Acidity'].value_counts(dropna = True)
# Out:
# Acidity
# 7.50    162
# 7.58    154
# 7.67    146
# 7.42    129
# 7.75    126
# 7.33    111
# 7.25     86
# 7.83     78
# 7.17     74
# 8.00     50
# 7.92     47
# 7.08     36
# 7.00     32
# 8.08     25
# 8.17     14
# 6.83     12
# 6.92     10
# 8.33      9
# 8.50      7
# 8.42      6
# 8.25      6
# 6.75      6
# 6.67      5
# 6.25      1
# 6.50      1
# 6.08      1
# 8.75      1
# 5.25      1
# 7.63      1
# 8.58      1
# 0.00      1
# Name: count, dtype: int64

# %%
df_quality_v3['Body'].value_counts(dropna = True)
# Out:
# Body
# 7.50    201
# 7.67    154
# 7.58    138
# 7.33    131
# 7.42    127
# 7.75    111
# 7.25     87
# 7.83     85
# 7.17     68
# 7.92     52
# 7.08     37
# 7.00     34
# 8.00     34
# 8.08     21
# 6.92     12
# 8.17      7
# 8.25      7
# 8.33      6
# 6.83      4
# 6.75      4
# 8.50      3
# 8.42      3
# 6.67      2
# 6.33      2
# 6.42      1
# 0.00      1
# 6.50      1
# 5.08      1
# 7.63      1
# 5.25      1
# 7.38      1
# 8.58      1
# 5.17      1
# Name: count, dtype: int64

# %%
df_quality_v3['Balance'].value_counts(dropna = True)
# Out:
# Balance
# 7.50    176
# 7.67    148
# 7.58    131
# 7.42    121
# 7.75    107
# 7.83    101
# 7.33     99
# 7.17     72
# 7.25     64
# 7.00     47
# 8.00     46
# 7.92     42
# 7.08     41
# 6.92     26
# 6.83     23
# 8.17     17
# 8.08     16
# 8.25      8
# 6.75      7
# 8.42      7
# 8.58      7
# 8.50      7
# 8.33      7
# 6.67      4
# 6.58      3
# 6.17      3
# 8.75      2
# 6.50      2
# 6.33      1
# 6.42      1
# 6.08      1
# 0.00      1
# 5.25      1
# Name: count, dtype: int64

# %%
df_quality_v3['Uniformity'].value_counts(dropna = True)
# Out:
# Uniformity
# 10.00    1152
# 9.33      116
# 8.67       31
# 8.00       25
# 6.67        7
# 6.00        3
# 7.33        2
# 9.50        1
# 9.00        1
# 0.00        1
# Name: count, dtype: int64

# %%
df_quality_v3['Clean_Cup'].value_counts(dropna = True)
# Out:
# Clean_Cup
# 10.00    1219
# 9.33       61
# 8.67       16
# 6.67       13
# 8.00       13
# 6.00        6
# 5.33        3
# 7.33        3
# 2.67        2
# 0.00        2
# 1.33        1
# Name: count, dtype: int64

# %%
df_quality_v3['Sweetness'].value_counts(dropna = True)
# Out:
# Sweetness
# 10.00    1218
# 9.33       61
# 8.67       12
# 8.00       11
# 6.67        8
# 7.75        7
# 7.58        5
# 6.00        3
# 7.42        3
# 7.92        2
# 7.67        2
# 7.83        2
# 0.00        1
# 7.50        1
# 1.33        1
# 8.42        1
# 7.08        1
# Name: count, dtype: int64

# %%
df_quality_v3['Moisture'].value_counts(dropna = True)
# Out:
# Moisture
# 0.11    383
# 0.12    294
# 0.00    264
# 0.10    182
# 0.13     76
# 0.09     27
# 0.14     23
# 0.08     16
# 0.01     15
# 0.15      8
# 0.05      8
# 0.02      7
# 0.06      7
# 0.07      5
# 0.16      5
# 0.04      4
# 0.03      4
# 0.20      3
# 0.17      3
# 0.18      2
# 0.28      1
# 0.21      1
# 0.22      1
# Name: count, dtype: int64

# %%
df_quality_v3['Quakers'].value_counts(dropna = True)
# Out:
# Quakers
# 0     1245
# 1       39
# 2       30
# 4        5
# 5        5
# 3        5
# 6        4
# 7        3
# 11       1
# 9        1
# 8        1
# Name: count, dtype: int64

# %%
df_quality_v3['Category_One_Defects'].value_counts(dropna = True)
# Out:
# Category_One_Defects
# 0     1137
# 1      101
# 2       38
# 3       18
# 4       16
# 5        9
# 10       4
# 6        3
# 7        3
# 31       2
# 9        1
# 20       1
# 8        1
# 11       1
# 15       1
# 23       1
# 12       1
# 63       1
# Name: count, dtype: int64

# %%
df_quality_v3['Category_Two_Defects'].value_counts(dropna = True)
# Out:
# Category_Two_Defects
# 0     373
# 1     207
# 2     182
# 3     134
# 4     118
# 5      73
# 6      44
# 7      41
# 8      29
# 9      23
# 10     21
# 12     13
# 13      9
# 14      9
# 20      8
# 11      8
# 17      7
# 16      6
# 15      6
# 19      3
# 26      3
# 21      2
# 29      2
# 18      2
# 23      2
# 30      2
# 47      1
# 24      1
# 27      1
# 28      1
# 31      1
# 40      1
# 38      1
# 45      1
# 34      1
# 22      1
# 32      1
# 55      1
# Name: count, dtype: int64

# %%
# Reset configuration
pd.reset_option('display.max_rows')

# %%
# Copy dataframe
df_quality_v4 = df_quality_v3.copy()

# %% [markdown]
# ## 3.5. Missing values

# %%
# Null values
df_quality_v4.isnull().sum()
# Out:
# Species                   0
# Continent_of_Origin       1
# Country_of_Origin         1
# Harvest_Year             60
# Expiration                0
# Variety                 226
# Color                   270
# Processing_Method       170
# Aroma                     0
# Flavor                    0
# Aftertaste                0
# Acidity                   0
# Body                      0
# Balance                   0
# Uniformity                0
# Clean_Cup                 0
# Sweetness                 0
# Moisture                  0
# Quakers                   0
# Category_One_Defects      0
# Category_Two_Defects      0
# dtype: int64

# %%
# Extract records with null values
df_null_values = df_quality_v4[df_quality_v4.isnull().any(axis = 1)]

# View subset
df_null_values
# Out:
#       Species Continent_of_Origin Country_of_Origin Harvest_Year Expiration  \
# 0     Arabica              Africa          Ethiopia   2014-01-01 2016-04-03
# 2     Arabica       North America         Guatemala          NaT 2011-05-31
# 3     Arabica              Africa          Ethiopia   2014-01-01 2016-03-25
# 5     Arabica       South America            Brazil   2013-01-01 2014-09-03
# 7     Arabica              Africa          Ethiopia   2010-01-01 2011-09-02
# ...       ...                 ...               ...          ...        ...
# 1334  Robusta       South America           Ecuador   2016-01-01 2017-01-18
# 1335  Robusta       South America           Ecuador   2016-01-01 2017-01-18
# 1336  Robusta       North America     United States   2014-01-01 2015-12-23
# 1337  Robusta                Asia             India   2013-01-01 2015-08-25
# 1338  Robusta                Asia           Vietnam   2013-01-01 2015-08-25
#
#       Variety         Color Processing_Method  Aroma  Flavor  ...  Acidity  \
# 0         NaN         Green      Washed / Wet   8.67    8.83  ...     8.75
# 2     Bourbon           NaN               NaN   8.42    8.50  ...     8.42
# 3         NaN         Green     Natural / Dry   8.17    8.58  ...     8.42
# 5         NaN  Bluish-Green     Natural / Dry   8.58    8.42  ...     8.50
# 7         NaN           NaN               NaN   8.25    8.33  ...     8.42
# ...       ...           ...               ...    ...     ...  ...      ...
# 1334      NaN    Blue-Green               NaN   7.75    7.58  ...     7.58
# 1335      NaN    Blue-Green               NaN   7.50    7.67  ...     7.75
# 1336      NaN           NaN     Natural / Dry   7.33    7.33  ...     7.42
# 1337      NaN         Green     Natural / Dry   7.42    6.83  ...     7.17
# 1338      NaN           NaN     Natural / Dry   6.75    6.67  ...     6.83
#
#       Body  Balance  Uniformity  Clean_Cup  Sweetness  Moisture  Quakers  \
# 0     8.50     8.42       10.00      10.00      10.00      0.12        0
# 2     8.33     8.42       10.00      10.00      10.00      0.00        0
# 3     8.50     8.25       10.00      10.00      10.00      0.11        0
# 5     8.25     8.33       10.00      10.00      10.00      0.11        0
# 7     8.33     8.50       10.00      10.00       9.33      0.03        0
# ...    ...      ...         ...        ...        ...       ...      ...
# 1334  5.08     7.83       10.00      10.00       7.75      0.00        0
# 1335  5.17     5.25       10.00      10.00       8.42      0.00        0
# 1336  7.50     7.17        9.33       9.33       7.42      0.00        0
# 1337  7.25     7.00        9.33       9.33       7.08      0.10        0
# 1338  6.92     6.83        9.33       9.33       6.67      0.12        0
#
#       Category_One_Defects  Category_Two_Defects
# 0                        0                     0
# 2                        0                     0
# 3                        0                     2
# 5                        0                     1
# 7                        0                     0
# ...                    ...                   ...
# 1334                     0                     1
# 1335                     0                     0
# 1336                     0                     6
# 1337                    20                     1
# 1338                    63                     9
#
# [393 rows x 21 columns]

# %%
# Remove records with null values
df_quality_v5 = df_quality_v4[~df_quality_v4.isnull().any(axis = 1)]

# Dimensions
df_quality_v5.shape
# Out:
# (946, 21)

# %% [markdown]
# ## 3.6. Mixed-type data

# %%
# Find mixed type data
for col in df_quality_v5.columns.tolist():
    weird = (df_quality_v5[[col]].map(type) != df_quality_v5[[col]].iloc[0].apply(type)).any(axis=1)
    if len(df_quality_v5[weird]) > 0:
        print (col)

# %%
# Copy dataframe
df_quality_v6 = df_quality_v5.copy()

# %% [markdown]
# ## 3.7. Duplicates

# %%
# Find duplicates
df_duplicates = df_quality_v6[df_quality_v6.duplicated()]

# View subset
df_duplicates
# Out:
#      Species Continent_of_Origin Country_of_Origin Harvest_Year Expiration  \
# 742  Arabica                Asia            Taiwan   2013-01-01 2014-12-26
#
#     Variety  Color Processing_Method  Aroma  Flavor  ...  Acidity  Body  \
# 742  Typica  Green      Washed / Wet    7.5     7.5  ...      7.5   7.5
#
#      Balance  Uniformity  Clean_Cup  Sweetness  Moisture  Quakers  \
# 742      7.5        10.0       10.0       10.0      0.11        0
#
#      Category_One_Defects  Category_Two_Defects
# 742                     0                     0
#
# [1 rows x 21 columns]

# %%
# Drop duplicates
df_quality_v7 = df_quality_v6.drop_duplicates()

# Dimensions
df_quality_v7.shape
# Out:
# (945, 21)

# %% [markdown]
# # 4. Exports

# %%
# Descriptive statistics - Cleaned dataset
df_quality_v7.describe()
# Out:
#                         Harvest_Year                     Expiration  \
# count                            945                            945
# mean   2013-10-20 22:43:48.571428608  2015-07-11 04:43:25.714285568
# min              2011-01-01 00:00:00            2012-11-10 00:00:00
# 25%              2012-01-01 00:00:00            2013-09-19 00:00:00
# 50%              2014-01-01 00:00:00            2015-05-26 00:00:00
# 75%              2015-01-01 00:00:00            2016-10-07 00:00:00
# max              2018-01-01 00:00:00            2019-01-19 00:00:00
# std                              NaN                            NaN
#
#             Aroma      Flavor  Aftertaste     Acidity        Body    Balance  \
# count  945.000000  945.000000  945.000000  945.000000  945.000000  945.00000
# mean     7.564984    7.513735    7.392815    7.530582    7.508296    7.50946
# min      5.080000    6.080000    6.170000    5.250000    6.330000    6.08000
# 25%      7.420000    7.330000    7.250000    7.330000    7.330000    7.33000
# 50%      7.580000    7.500000    7.420000    7.500000    7.500000    7.50000
# 75%      7.750000    7.670000    7.580000    7.670000    7.670000    7.67000
# max      8.750000    8.670000    8.500000    8.580000    8.420000    8.58000
# std      0.291573    0.311277    0.319015    0.294613    0.261814    0.32606
#
#        Uniformity   Clean_Cup   Sweetness    Moisture     Quakers  \
# count  945.000000  945.000000  945.000000  945.000000  945.000000
# mean     9.861556    9.848265    9.920085    0.095249    0.164021
# min      6.000000    1.330000    1.330000    0.000000    0.000000
# 25%     10.000000   10.000000   10.000000    0.100000    0.000000
# 50%     10.000000   10.000000   10.000000    0.110000    0.000000
# 75%     10.000000   10.000000   10.000000    0.120000    0.000000
# max     10.000000   10.000000   10.000000    0.170000   11.000000
# std      0.458965    0.703070    0.448902    0.041779    0.782202
#
#        Category_One_Defects  Category_Two_Defects
# count            945.000000            945.000000
# mean               0.415873              3.606349
# min                0.000000              0.000000
# 25%                0.000000              0.000000
# 50%                0.000000              2.000000
# 75%                0.000000              4.000000
# max               31.000000             47.000000
# std                2.004646              5.355336

# %%
# Export cleaned dataset
df_quality_v7.to_pickle(os.path.join(path, 'prepared', 'coffee_quality_cleaned.pkl'))
