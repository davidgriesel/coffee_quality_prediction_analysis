# %% [markdown]
# # Contents
# 1. Imports
# 2. Checks
# 3. Cleaning
# 4. Visual Exploration
# 5. Hypotheses

# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Path
path = r'/Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling'

# %%
# Dataset
df_quality = pd.read_pickle(os.path.join(path, 'data', 'prepared','coffee_quality_cleaned.pkl'))

# %%
# Configuration
# %matplotlib inline

# %% [markdown]
# # 2. Checks

# %%
# Dimensions
df_quality.shape
# Out:
# (945, 21)

# %%
# Preview
df_quality.head()
# Out:
#     Species Continent_of_Origin Country_of_Origin Harvest_Year Expiration  \
# 1   Arabica              Africa          Ethiopia   2014-01-01 2016-04-03
# 4   Arabica              Africa          Ethiopia   2014-01-01 2016-04-03
# 6   Arabica       South America              Peru   2012-01-01 2013-09-17
# 9   Arabica              Africa          Ethiopia   2014-01-01 2016-03-29
# 18  Arabica                Asia             China   2015-01-01 2017-04-07
#
#     Variety         Color Processing_Method  Aroma  Flavor  ...  Acidity  \
# 1     Other         Green      Washed / Wet   8.75    8.67  ...     8.58
# 4     Other         Green      Washed / Wet   8.25    8.50  ...     8.50
# 6     Other  Bluish-Green      Washed / Wet   8.42    8.50  ...     8.50
# 9     Other         Green     Natural / Dry   8.08    8.58  ...     8.50
# 18  Catimor         Green      Washed / Wet   8.42    8.25  ...     8.17
#
#     Body  Balance  Uniformity  Clean_Cup  Sweetness  Moisture  Quakers  \
# 1   8.42     8.42        10.0       10.0       10.0      0.12        0
# 4   8.42     8.33        10.0       10.0       10.0      0.12        0
# 6   8.25     8.25        10.0       10.0       10.0      0.11        0
# 9   7.67     8.42        10.0       10.0       10.0      0.10        0
# 18  7.92     8.00        10.0       10.0       10.0      0.10        0
#
#     Category_One_Defects  Category_Two_Defects
# 1                      0                     1
# 4                      0                     2
# 6                      0                     0
# 9                      0                     4
# 18                     0                     0
#
# [5 rows x 21 columns]

# %% [markdown]
# # 3. Checking for extreme values

# %% [markdown]
# ## 3.2. Flavor

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df_quality['Flavor'], bins=100, kde=True)

# Add labels and title
#plt.title("Distribution of Aroma Scores")
#plt.xlabel("")
#plt.ylabel("")

# Adjust layout
plt.tight_layout()

# Define export path
save_path = os.path.join(path, 'visualisations', 'hist_flavour.png')

# Ensure directory exists
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# Print confirmation
print(f"Chart successfully saved at: {save_path}")
# Out:
# Chart successfully saved at: /Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling/visualisations/hist_flavour.png

# %%
# Basic statistics - Flavor

# %%
df_quality['Flavor'].min()
# Out:
# 6.08

# %%
df_quality['Flavor'].max()
# Out:
# 8.67

# %%
df_quality['Flavor'].mean()
# Out:
# 7.513735449735449

# %%
df_quality['Flavor'].median()
# Out:
# 7.5

# %% [markdown]
# ##### Mean and median are close suggesting only a slight skew.

# %% [markdown]
# ## 3.3. Aftertaste

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df_quality['Aftertaste'], bins=100, kde=True)

# Add labels and title
#plt.title("Distribution of Aroma Scores")
#plt.xlabel("")
#plt.ylabel("")

# Adjust layout
plt.tight_layout()

# Define export path
save_path = os.path.join(path, 'visualisations', 'hist_aftertaste.png')

# Ensure directory exists
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# Print confirmation
print(f"Chart successfully saved at: {save_path}")
# Out:
# Chart successfully saved at: /Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling/visualisations/hist_aftertaste.png

# %%
# Basic statistics - Aftertaste

# %%
df_quality['Aftertaste'].min()
# Out:
# 6.17

# %%
df_quality['Aftertaste'].max()
# Out:
# 8.5

# %%
df_quality['Aftertaste'].mean()
# Out:
# 7.392814814814815

# %%
df_quality['Aftertaste'].median()
# Out:
# 7.42

# %% [markdown]
# ##### Mean and median are close suggesting only a slight skew.

# %% [markdown]
# ## 3.4. Acidity

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df_quality['Acidity'], bins=100, kde=True)

# Add labels and title
#plt.title("Distribution of Aroma Scores")
#plt.xlabel("")
#plt.ylabel("")

# Adjust layout
plt.tight_layout()

# Define export path
save_path = os.path.join(path, 'visualisations', 'hist_acidity.png')

# Ensure directory exists
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# Print confirmation
print(f"Chart successfully saved at: {save_path}")
# Out:
# Chart successfully saved at: /Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling/visualisations/hist_acidity.png

# %%
# Basic statistics - Acidity

# %%
df_quality['Acidity'].min()
# Out:
# 5.25

# %%
df_quality['Acidity'].max()
# Out:
# 8.58

# %%
df_quality['Acidity'].mean()
# Out:
# 7.53058201058201

# %%
df_quality['Acidity'].median()
# Out:
# 7.5

# %% [markdown]
# ##### Mean and median are close suggesting only a slight skew.

# %% [markdown]
# ## 3.5. Body

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df_quality['Body'], bins=100, kde=True)

# Add labels and title
#plt.title("Distribution of Aroma Scores")
#plt.xlabel("")
#plt.ylabel("")

# Adjust layout
plt.tight_layout()

# Define export path
save_path = os.path.join(path, 'visualisations', 'hist_body.png')

# Ensure directory exists
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# Print confirmation
print(f"Chart successfully saved at: {save_path}")
# Out:
# Chart successfully saved at: /Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling/visualisations/hist_body.png

# %%
# Basic statistics - Body

# %%
df_quality['Body'].min()
# Out:
# 6.33

# %%
df_quality['Body'].max()
# Out:
# 8.42

# %%
df_quality['Body'].mean()
# Out:
# 7.5082962962962965

# %%
df_quality['Body'].median()
# Out:
# 7.5

# %% [markdown]
# ##### Mean and median are close suggesting only a slight skew.

# %% [markdown]
# ## 3.6. Balance

# %%
# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(df_quality['Balance'], bins=100, kde=True)

# Add labels and title
#plt.title("Distribution of Aroma Scores")
#plt.xlabel("")
#plt.ylabel("")

# Adjust layout
plt.tight_layout()

# Define export path
save_path = os.path.join(path, 'visualisations', 'hist_balance.png')

# Ensure directory exists
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save the figure
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# Print confirmation
print(f"Chart successfully saved at: {save_path}")
# Out:
# Chart successfully saved at: /Users/davidgriesel/Documents/GitHub/06_coffee_quality_modelling/visualisations/hist_balance.png

# %%
# Basic statistics - Balance

# %%
df_quality['Balance'].min()
# Out:
# 6.08

# %%
df_quality['Balance'].max()
# Out:
# 8.58

# %%
df_quality['Balance'].mean()
# Out:
# 7.509460317460318

# %%
df_quality['Balance'].median()
# Out:
# 7.5

# %% [markdown]
# ##### Mean and median are close suggesting only a slight skew.

# %% [markdown]
# # 4. Visual exploration

# %% [markdown]
# ##### Variables with strongest correlation from Exercise 3.2:
# - Aftertaste vs Flavor
# - Aftertaste vs Balance
# - Flavor vs Acidity
# - Flavor vs Balance
# - Flavor vs Aroma
# - Balance vs Body<br><br>

# %% [markdown]
# ## 4.1. Aftertaste vs Flavor

# %%
# Scatterplot
df_quality.plot(x = 'Aftertaste', y = 'Flavor',style = 'o')
plt.title('Aftertaste vs Flavor')  
plt.xlabel('Aftertaste')  
plt.ylabel('Flavour')  
plt.show()

# %% [markdown]
# ## 4.2. Aftertaste vs Balance

# %%
# Scatterplot
df_quality.plot(x = 'Aftertaste', y = 'Balance',style = 'o')
plt.title('Aftertaste vs Balance')  
plt.xlabel('Aftertaste')  
plt.ylabel('Balance')  
plt.show()

# %% [markdown]
# ## 4.3. Flavor vs Acidity

# %%
# Scatterplot
df_quality.plot(x = 'Flavor', y = 'Acidity',style = 'o')
plt.title('Flavor vs Acidity')  
plt.xlabel('Flavor')  
plt.ylabel('Acidity')  
plt.show()

# %% [markdown]
# ## 4.4. Flavor vs Balance

# %%
# Scatterplot
df_quality.plot(x = 'Flavor', y = 'Balance',style = 'o')
plt.title('Flavor vs Balance')  
plt.xlabel('Flavor')  
plt.ylabel('Balance')  
plt.show()

# %% [markdown]
# ## 4.5. Flavor vs Aroma

# %%
# Scatterplot
df_quality.plot(x = 'Flavor', y = 'Aroma',style = 'o')
plt.title('Flavor vs Aroma')  
plt.xlabel('Flavor')  
plt.ylabel('Aroma')  
plt.show()

# %% [markdown]
# ## 4.6. Balance vs Body

# %%
# Scatterplot
df_quality.plot(x = 'Balance', y = 'Body',style = 'o')
plt.title('Balance vs Body')  
plt.xlabel('Balance')  
plt.ylabel('Body')  
plt.show()

# %% [markdown]
# # 5. Hypotheses

# %% [markdown]
# ##### The following variables appear most frequently among those with the strongest correlations:
# - Aftertaste
# - Flavor
# - Balance<br><br>
#
# ##### Hypothesis #1
# - The higher the score for Aftertaste, the higher the score for Flavor would be.<br><br>
#
# ##### Hypothesis #2
# - The higher the score for Aftertaste, the higher the score for Balance would be.<br><br>

# %% [markdown]
# ## 5.1. Hypothesis #1

# %% [markdown]
# ### 5.1.1. Reshape variables

# %%
# Reshape variables
X1 = df_quality['Aftertaste'].values.reshape(-1,1)
y1 = df_quality['Flavor'].values.reshape(-1,1)

# %% [markdown]
# ### 5.1.2. Split data

# %%
# Split data
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.3, random_state = 0)

# %% [markdown]
# ### 5.1.3. Linear regression

# %%
# Create regression object
regression_1 = LinearRegression()

# %%
# Fit the regression object onto the training set
regression_1.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
# Predict the values of y1 using X1
y1_predicted = regression_1.predict(X1_test)

# %% [markdown]
# ### 5.1.4. Regression plot

# %%
# Plot the modelled regression - test set
plot_test_1 = plt
plot_test_1.scatter(X1_test, y1_test, color = 'gray', s = 15)
plot_test_1.plot(X1_test, y1_predicted, color = 'red', linewidth = 3)
plot_test_1.title('Aftertaste vs Flavor (Test set)')
plot_test_1.xlabel('Aftertaste')
plot_test_1.ylabel('Flavor')
plot_test_1.show()

# %% [markdown]
# ##### Comments
# - The data points appear to be evenly distributed around the regression line.

# %% [markdown]
# ### 5.1.5. Model performance statistics (Test set)

# %%
# Create objects that contain the model summary statistics
rmse_1 = mean_squared_error(y1_test, y1_predicted) 
r2_1 = r2_score(y1_test, y1_predicted)

# %%
# Print the model summary statistics
print('Slope:' ,regression_1.coef_)
print('Mean squared error: ', rmse_1)
print('R2 score: ', r2_1)
# Out:
# Slope: [[0.77654044]]
# Mean squared error:  0.031563293173207344
# R2 score:  0.7305230539312092

# %% [markdown]
# ### 5.1.6. Actual vs predicted y-values

# %%
# Create a dataframe comparing the actual and predicted values of y1
data_1 = pd.DataFrame({'Actual': y1_test.flatten(), 'Predicted': y1_predicted.flatten()})
data_1.head(30)
# Out:
#     Actual  Predicted
# 0     7.50   7.536944
# 1     7.33   7.342809
# 2     7.33   7.467055
# 3     8.17   7.793202
# 4     7.58   7.404932
# 5     7.67   7.661190
# 6     7.33   7.404932
# 7     7.17   7.210797
# 8     7.08   7.148674
# 9     7.42   7.599067
# 10    6.75   6.954538
# 11    7.83   7.467055
# 12    7.75   7.599067
# 13    7.50   7.599067
# 14    7.58   7.661190
# 15    7.50   7.467055
# 16    7.58   7.536944
# 17    7.75   7.731079
# 18    6.92   7.148674
# 19    7.50   7.210797
# 20    7.33   7.404932
# 21    7.67   7.342809
# 22    7.58   7.661190
# 23    7.50   7.404932
# 24    8.00   7.855325
# 25    7.42   7.272920
# 26    7.25   7.467055
# 27    7.67   7.536944
# 28    6.50   6.954538
# 29    7.58   7.661190

# %% [markdown]
# ##### Comments
# - The predicted y-values are fairly close to the actual y-values with some over, and some under.

# %% [markdown]
# ### 5.1.7. Model performance statistics (Training set)

# %%
# Predict
y1_predicted_train = regression_1.predict(X1_train)

# %%
# Create objects that contain the model summary statistics
rmse_1 = mean_squared_error(y1_train, y1_predicted_train)
r2_1 = r2_score(y1_train, y1_predicted_train)

# %%
# Print the model summary statistics
print('Slope:' ,regression_1.coef_)
print('Mean squared error: ', rmse_1)
print('R2 score: ', r2_1)
# Out:
# Slope: [[0.77654044]]
# Mean squared error:  0.029287772376638082
# R2 score:  0.6660234980676127

# %%
# Visualizing the training set results
plot_test_1 = plt
plot_test_1.scatter(X1_train, y1_train, color='green', s = 15)
plot_test_1.plot(X1_train, y1_predicted_train, color='red', linewidth =3)
plot_test_1.title('Aftertaste vs Flavor (Train set)')
plot_test_1.xlabel('Aftertaste')
plot_test_1.ylabel('Flavor')
plot_test_1.show()

# %% [markdown]
# ### 5.1.8. Performance
# - The MSE is low, indicating predictions are close to actual values.
# - The R2 score indicates that 73.1% of the variance in Flavor is explained by Aftertaste.
# - Overall, the model explains a significant portion of the variance and makes predictions with relatively small errors.
# - The values between the test and training sets are also closely aligned, which suggests that the model performs consistently.

# %% [markdown]
# ## 5.2. Hypothesis #2

# %% [markdown]
# ### 5.2.1. Reshape variables

# %%
# Reshape variables
X2 = df_quality['Aftertaste'].values.reshape(-1,1)
y2 = df_quality['Balance'].values.reshape(-1,1)

# %% [markdown]
# ### 5.2.2. Split data

# %%
# Split data into 
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.3, random_state = 0)

# %% [markdown]
# ### 5.2.3. Linear regression

# %%
# Create regression object
regression_2 = LinearRegression()

# %%
# Fit the regression object onto the training set.
regression_2.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %%
# Predict the values of y using X2
y2_predicted = regression_2.predict(X2_test)

# %% [markdown]
# ### 5.2.4. Regression plot

# %%
# Plot the modelled regression - test set
plot_test_2 = plt
plot_test_2.scatter(X2_test, y2_test, color = 'gray', s = 15)
plot_test_2.plot(X2_test, y2_predicted, color = 'red', linewidth = 3)
plot_test_2.title('Aftertaste vs Balance (Test set)')
plot_test_2.xlabel('Aftertaste')
plot_test_2.ylabel('Balance')
plot_test_2.show()

# %% [markdown]
# ##### Comments
# - The data points appear to be evenly distributed around the regression line.

# %% [markdown]
# ### 5.2.5. Model performance statistics (Test set)

# %%
# Create objects that contain the model summary statistics
rmse_2 = mean_squared_error(y2_test, y2_predicted) 
r2_2 = r2_score(y2_test, y2_predicted)

# %%
# Print the model summary statistics
print('Slope:' ,regression_2.coef_)
print('Mean squared error: ', rmse_2)
print('R2 score: ', r2_2)
# Out:
# Slope: [[0.76497225]]
# Mean squared error:  0.055903300721692445
# R2 score:  0.536711950823576

# %% [markdown]
# ### 5.2.6. Actual vs predicted y-values

# %%
# Create a dataframe comparing the actual and predicted values of y2
data_2 = pd.DataFrame({'Actual': y2_test.flatten(), 'Predicted': y2_predicted.flatten()})
data_2.head(30)
# Out:
#     Actual  Predicted
# 0     7.50   7.526329
# 1     8.17   7.335086
# 2     7.42   7.457482
# 3     7.83   7.778770
# 4     8.58   7.396284
# 5     7.58   7.648725
# 6     7.42   7.396284
# 7     7.08   7.205041
# 8     7.08   7.143843
# 9     7.58   7.587527
# 10    7.00   6.952600
# 11    7.67   7.457482
# 12    7.75   7.587527
# 13    7.50   7.587527
# 14    7.58   7.648725
# 15    7.33   7.457482
# 16    7.50   7.526329
# 17    7.92   7.717572
# 18    7.00   7.143843
# 19    7.58   7.205041
# 20    7.42   7.396284
# 21    7.67   7.335086
# 22    7.42   7.648725
# 23    7.33   7.396284
# 24    7.83   7.839968
# 25    7.33   7.266238
# 26    7.33   7.457482
# 27    7.50   7.526329
# 28    7.17   6.952600
# 29    7.58   7.648725

# %% [markdown]
# ##### Comments
# - The predicted y-values are fairly close to the actual y-values with some over, and some under.

# %% [markdown]
# ### 5.2.7 Model performance statistics (Training set)

# %%
# Predict
y2_predicted_train = regression_2.predict(X2_train)

# %%
rmse_2 = mean_squared_error(y2_train, y2_predicted_train)
r2_2 = r2_score(y2_train, y2_predicted_train)

# %%
print('Slope:' ,regression_2.coef_)
print('Mean squared error: ', rmse_2)
print('R2 score: ', r2_2)
# Out:
# Slope: [[0.76497225]]
# Mean squared error:  0.04324945122605353
# R2 score:  0.5671963902761452

# %%
# Visualizing the training set results
plot_test_2 = plt
plot_test_2.scatter(X2_train, y2_train, color='green', s = 15)
plot_test_2.plot(X2_train, y2_predicted_train, color='red', linewidth =3)
plot_test_2.title('Aftertaste vs Balance (Train set)')
plot_test_2.xlabel('Aftertaste')
plot_test_2.ylabel('Balance')
plot_test_2.show()

# %% [markdown]
# ### 5.2.8 Performance
# - The MSE is low, indicating predictions are close to actual values.
# - The R2 score indicates that 73.05% of the variance in Balance is explained by Aftertaste.
# - Overall, the model explains a significant portion of the variance and makes predictions with relatively small errors.
# - The values between the test and training sets are also closely aligned, which suggests that the model performs consistently.
